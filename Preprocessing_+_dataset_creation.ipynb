# %% [markdown]
#  ## installing libraries and importing

# %%
# !pip install pandas numpy scikit-learn tensorflow matplotlib seaborn
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.10.5)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.10)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)

# %%
# !sudo dpkg --configure -a
# !sudo apt-get install -y tshark
# Out:
# Setting up wireshark-common (3.6.2-2) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# Setting up tshark (3.6.2-2) ...
# Processing triggers for hicolor-icon-theme (0.17-2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.8) ...
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for shared-mime-info (2.1-2) ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tshark is already the newest version (3.6.2-2).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
from sklearn.metrics import mean_squared_error

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau

# %% [markdown]
# ## Downloading dataset and unzipping it

# %%
# !wget -c -O scada_dataset.tar "https://g-83fdd0.1beed.03c0.data.globus.org/cartuids/14271_2329f583703f14b8991e1b9c259b8a4b.tar"

# checkin file size
# !ls -lh scada_dataset.tar

#  Extract the TAR archive


# !mkdir -p /content/scada_raw
# !tar -xvf scada_dataset.tar -C /content/scada_raw || true

# list what’s inside
# !find /content/scada_raw -maxdepth 3 -type f
# Out:
# --2025-11-09 14:51:37--  https://g-83fdd0.1beed.03c0.data.globus.org/cartuids/14271_2329f583703f14b8991e1b9c259b8a4b.tar
# Resolving g-83fdd0.1beed.03c0.data.globus.org (g-83fdd0.1beed.03c0.data.globus.org)... 192.101.102.34
# Connecting to g-83fdd0.1beed.03c0.data.globus.org (g-83fdd0.1beed.03c0.data.globus.org)|192.101.102.34|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/x-tar]
# Saving to: ‘scada_dataset.tar’
#
# scada_dataset.tar       [        <=>         ]   7.41G  67.8MB/s    in 1m 41s
#
# 2025-11-09 14:53:19 (75.4 MB/s) - ‘scada_dataset.tar’ saved [7957268480]
#
# -rw-r--r-- 1 root root 7.5G Nov  9 14:53 scada_dataset.tar
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/Physical Data/
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/Physical Data/Baseline.zip
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/Physical Data/Test3.zip
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Miscellaneous_PCAPs/
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Miscellaneous_PCAPs/test5.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Miscellaneous_PCAPs/binary_output.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Miscellaneous_PCAPs/baseline_02_07_20_11_40.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/AttackerVM_PCAPs/
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/AttackerVM_PCAPs/testcase5_spoofed_ip.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/AttackerVM_PCAPs/testcase5_AttackerVM.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/AttackerVM_PCAPs/testcase14_splitTCP_Operate_AttackerVM.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/AttackerVM_PCAPs/testcase14_splitTCP_AttackerVM.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/AttackerVM_PCAPs/testcase14_read_directoperate_AttackerVM.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/AttackerVM_PCAPs/testcase14_AttackerVM.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/AttackerVM_PCAPs/test5_results.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_SEL451U1/
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_SEL451U1/mDNP-172.17.0.19-tcp_handshake_stop.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_SEL451U1/mDNP-172.17.0.19-tcp_handshake_start.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_SEL451U1/mDNP-172.17.0.19-dnp3_File_Read.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_SEL451U1/mDNP-172.17.0.19-dnp3_File_Info.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_SEL451U1/mDNP-172.17.0.19-dnp3_class0123.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_SEL451U1/mDNP-172.17.0.19-dnp3_Binary_Counter.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_SEL351U2/
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_SEL351U2/mDNP-172.17.0.18-tcp_handshake_stop.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_SEL351U2/mDNP-172.17.0.18-tcp_handshake_start.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_SEL351U2/mDNP-172.17.0.18-dnp3_device_attr_variation.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_SEL351U2/mDNP-172.17.0.18-dnp3_class0123.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_SEL351U1/
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_SEL351U1/mDNP-172.17.0.16-tcp_handshake_stop.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_SEL351U1/mDNP-172.17.0.16-tcp_handshake_start.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_SEL351U1/mDNP-172.17.0.16-dnp3_class0123.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_SAGERTU/
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_SAGERTU/mMB-172.17.0.60-tcp_handshake_start.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_SAGERTU/mMB-172.17.0.60-modbus_read_input_registers_all.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_SAGERTU/mMB-172.17.0.60-modbus_read_holding_registers_all.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_SAGERTU/mMB-172.17.0.60-modbus_read_discrete_all.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_SAGERTU/mMB-172.17.0.60-modbus_readcoils_all.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_SAGERTU/mDNP-172.17.0.60-tcp_handshake_stop.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_SAGERTU/mDNP-172.17.0.60-tcp_handshake_start.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_SAGERTU/mDNP-172.17.0.60-dnp3_device_attr_variation.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_SAGERTU/mDNP-172.17.0.60-dnp3_class0123.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GEL90/
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GEL90/mDNP-172.17.0.22-tcp_handshake_stop.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GEL90/mDNP-172.17.0.22-tcp_handshake_start.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GEL90/mDNP-172.17.0.22-dnp3_class0123.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-tcp_handshake_stop.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-tcp_handshake_start.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Virtual_Terminal_Events.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Security_Statistic_Events_variation2.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Security_Statistic_Events_variation1.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Security_Statistic.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_record_time.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Octet_String_Object.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Octet_String_Event_Object.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Internal_Indications.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Frozen_Counter_Events_32-Bit_with_Time.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Frozen_Counter_Events_32-Bit_without_Time.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Frozen_Counter_Events_16-Bit_with_Time.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Frozen_Counter_Events_16-Bit_without_Time.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Frozen_Counter_Events.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Frozen_Counters_32-Bit_with_Time_of_Freeze.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Frozen_Counters_32-Bit_with_Flag.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Frozen_Counters_32-Bit_without_Flag.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Frozen_Counters_16-Bit_with_Time_of_Freeze.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Frozen_Counters_16-Bit_with_Flag.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Frozen_Counters_16-Bit_without_Flag.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Frozen_Counters.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_File_Info.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_enable_unsol.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Double_Bit_Input_with_Status.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Double_Bit_Input_packed_without_Status.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Double_Bit_Input_Change_with_Relative_Time.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Double_Bit_Input_Change_without_Time.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Double_Bit_Input_Change.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Double_Bit_Input.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_disable_unsol.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_device_attr_variation.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_device_attr.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Data_Set_Value.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Data_Set_Prototype.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Data_Set_Event.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Data_Set_Descriptor_variation3.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Data_Set_Descriptor_variation1.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Data Set Descriptor_variation2.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Counter_Change_Event_32-Bit_with_Time.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Counter_Change_Event_32-Bit_without_Time.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Counter_Change_Event_16-Bit_with_Time.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Counter_Change_Event_16-Bit_without_Time.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Counter_Change_Event.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Class_3_Data.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Class_2_Data.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Class_1_Data.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_class0123.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Binary_Output_with_status.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Binary_Output_Packed_without_status.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Binary_Output.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Binary_Input_with_Status.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Binary_Input_packed_without_status.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Binary_Input_Change_with_Time.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Binary_Input_Change_with_Relative_Time.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Binary_Input_Change_without_Time.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Binary_Input_Change.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Binary_Counter_32-Bit_with_Flag.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Binary_Counter_32-Bit_without_Flag.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Binary_Input.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Binary_Counter_16-Bit_with_Flag.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Binary_Counter_16-Bit_without_Flag.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Binary_Counter.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Analog_Output_Status_Short_Floating_Point_(32-Bit).pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Analog_Output_Status_Long_Floating_Point_(64-Bit).pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Analog_Output_Status_32-Bit.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Analog_Output_Status_16-Bit.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Analog_Output_Status.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Analog_Input_Short_Floating_Point_(32-Bit).pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Analog_Input_Long_Floating_Point_(64-Bit).pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Analog_Input_Deadband_Floating_Point.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Analog_Input_Deadband_32-Bit.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Analog_Input_Deadband_16-Bit.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Analog_Input_Deadband.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Analog_Input_32-Bit_with_Flag.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Analog_Input_32-Bit_without_Flag.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Analog_Input_16-Bit_with_Flag.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Analog_Input_16-Bit_without_Flag.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Analog_Input.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Analog_Change_Event_Short_Float_with_Time.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Analog_Change_Event_Short_Float_without_Time.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Analog_Change_Event_Long_Float_with_Time.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Analog_Change_Event_Long_Float_without_Time.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Analog_Change_Event_32-Bit_with_Time.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Analog_Change_Event_32-Bit_without_Time.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Analog_Change_Event_16-Bit_with_Time.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Analog_Change_Event.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_Analog_Change_Event_16-Bit_without_Time.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_GED30/mDNP-172.17.0.21-dnp3_8bitstartstop.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_CWIO1/
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_CWIO1/mMB-172.17.0.38-tcp_handshake_start.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_CWIO1/mMB-172.17.0.38-modbus_read_input_registers_all.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_CWIO1/mMB-172.17.0.38-modbus_read_holding_registers_all.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_CWIO1/mMB-172.17.0.38-modbus_read_discrete_all.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_CWIO1/mMB-172.17.0.38-modbus_readcoils_all.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_CWIO0/
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_CWIO0/mMB-172.17.0.29-tcp_handshake_start.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_CWIO0/mMB-172.17.0.29-modbus_read_input_registers_all.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_CWIO0/mMB-172.17.0.29-modbus_read_holding_registers_all.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_CWIO0/mMB-172.17.0.29-modbus_read_discrete_all.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/PTH_Device_PCAPs/DEN_CWIO0/mMB-172.17.0.29-modbus_readcoils_all.pcapng
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase9_run2.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase9_run1.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase8_run7.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase8_run6.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase8_run5.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase8_run4.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase8_run3.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase8_run2.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase8_run1.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase7_run7.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase7_run6.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase7_run5.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase7_run4.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase7_run3.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase7_run2.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase7_run1.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase6_run9.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase6_run8.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase6_run7.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase6_run6.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase6_run5.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase6_run4.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase6_run3.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase6_run2.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase6_run11.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase6_run10.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase6_run1.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase5_run3.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase5_run2.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase5_run1.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase4_run1.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase3_run5.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase3_run4.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase3_run3.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase3_run2_sage_14_28.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase3_run2.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase3_run1_sage_11_30.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase3_run1.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase2_run3.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase2_run2.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase2_run1_10_57.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase14_run4.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase14_run3.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase14_run2.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase14_run1.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase13_run5.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase13_run4.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase13_run3.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase13_run2.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase13_run1.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase12_run1.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase11_run2.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase11_run1.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Testcase_PCAPs/testcase10_run1.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Long_duration_PCAPs/
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Long_duration_PCAPs/baseline_02_07_20_16_00.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Long_duration_PCAPs/baseline_02_08_20_13_30.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Long_duration_PCAPs/day6_03_19_20.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Long_duration_PCAPs/day5_night.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Long_duration_PCAPs/day5_03_18_20.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Long_duration_PCAPs/day4_night.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Long_duration_PCAPs/day4_03_17_20.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Long_duration_PCAPs/day3_night.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Long_duration_PCAPs/day3_03_16_20.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Long_duration_PCAPs/day2_02_14_20.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data/PCAPs/Long_duration_PCAPs/day1_02_10_20.pcap
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data.zip
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/Detailed Data descriptions.pdf
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/README.txt
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/SCADA_DATA_TAP_Config.png
# 14271_2329f583703f14b8991e1b9c259b8a4b.tar/SCADA Data Environment Description.pdf
# /content/scada_raw/14271_2329f583703f14b8991e1b9c259b8a4b.tar/README.txt
# /content/scada_raw/14271_2329f583703f14b8991e1b9c259b8a4b.tar/Detailed Data descriptions.pdf
# /content/scada_raw/14271_2329f583703f14b8991e1b9c259b8a4b.tar/SCADA_DATA_TAP_Config.png
# /content/scada_raw/14271_2329f583703f14b8991e1b9c259b8a4b.tar/SCADA Data Environment Description.pdf
# /content/scada_raw/14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data.zip

# %%
# Unzip Data.zip
import os
import zipfile

data_zip_path = "/content/scada_raw/14271_2329f583703f14b8991e1b9c259b8a4b.tar/Data.zip"
extract_dir = "/content/scada_data/"
os.makedirs(extract_dir, exist_ok=True)

with zipfile.ZipFile(data_zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

print(" Data.zip extracted to:", extract_dir)
# Out:
#  Data.zip extracted to: /content/scada_data/

# %% [markdown]
# ## Converting the pcaps (native wireshark format) to csvs

# %%
import os, subprocess

pcap_dir = "/content/scada_data/Data/PCAPs/Long_duration_PCAPs"
csv_dir = "/content/scada_csv"
os.makedirs(csv_dir, exist_ok=True)

# Tshark fields based on the paper
fields = [
    "frame.number",
    "frame.time_relative",
    "ip.src",
    "ip.dst",
    "_ws.col.Protocol",
    "frame.len",
    "_ws.col.Info"
]

selected_pcaps = [
    "day1_02_10_20.pcap",
    "day3_03_16_20.pcap",
    "day4_03_17_20.pcap",
    "day5_03_18_20.pcap",
    "day6_03_19_20.pcap"
]

# helper function run a shell command and capture output
def run_cmd(cmd):
    result = subprocess.run(cmd, shell=True, capture_output=True, text=True)
    return result.stdout.strip(), result.stderr.strip()

for fname in selected_pcaps:
    input_path = os.path.join(pcap_dir, fname)
    output_path = os.path.join(csv_dir, fname.replace(".pcap", ".csv"))

    print(f"\n Inspecting {fname} ...")

    # 1️⃣ Check if file exists and summarize basic info
    if not os.path.exists(input_path):
        print(f"File not found: {input_path}")
        continue

    # Count packets quickly
    out, _ = run_cmd(f"tshark -r '{input_path}' -q -z io,phs")
    lines = out.splitlines()
    total_packets = [l for l in lines if "Frames" in l]
    if total_packets:
        print(f" Summary of I/O Phases:")
        for l in total_packets[:10]:
            print("   ", l)
    else:
        print("Could not summarize PCAP structure.")

    # 2 Check available fields (display filter names)
    print("\n🔎 Checking field existence:")
    out, _ = run_cmd("tshark -G fields | grep 'ip.' | head -5")
    print("   Example IP-related fields:", out.splitlines()[:3])
    out, _ = run_cmd("tshark -G fields | grep 'frame.' | head -5")
    print("   Example Frame-related fields:", out.splitlines()[:3])
    out, _ = run_cmd("tshark -G fields | grep '_ws.col.Protocol'")
    print("   _ws.col.Protocol found:", bool(out.strip()))

    # 3 Test extract first 10 packets to preview columns
    preview_cmd = (
        f"tshark -r '{input_path}' -T fields "
        f"-E header=y -E separator=, "
        + " ".join([f"-e {f}" for f in fields])
        + " -c 10"
    )
    preview_out, preview_err = run_cmd(preview_cmd)
    print("\n🧾 Preview of first 10 packets:\n", preview_out[:500])
    if preview_err:
        print(" Tshark warnings/errors:\n", preview_err)

    #  Now convert full file → CSV
    print(f"\n🚀 Converting {fname} → {os.path.basename(output_path)} ...")
    cmd = [
        "tshark",
        "-r", input_path,
        "-T", "fields",
        "-E", "header=y",
        "-E", "separator=,",
        *sum([["-e", f] for f in fields], [])
    ]
    with open(output_path, "w") as f:
        subprocess.run(cmd, stdout=f)
    print(f" Done: {output_path}\n")
# Out:
#  Inspecting day1_02_10_20.pcap ...
# Could not summarize PCAP structure.
#
# 🔎 Checking field existence:
#    Example IP-related fields: ['F\tDescriptor Type\tieee17221.descriptor_type\tFT_UINT16\tieee17221\tBASE_HEX\t0x0\t', 'F\tDescriptor Index\tieee17221.descriptor_index\tFT_UINT16\tieee17221\tBASE_HEX\t0x0\t', 'F\tLocalized Description\tieee17221.configuration_name_string\tFT_UINT16\tieee17221\tBASE_DEC\t0x0\t']
#    Example Frame-related fields: ['F\tFrames TX\tieee17221.frames_tx\tFT_UINT32\tieee17221\tBASE_DEC\t0x0\t', 'F\tFrames RX\tieee17221.frames_rx\tFT_UINT32\tieee17221\tBASE_DEC\t0x0\t', 'F\tIncorrect frame dependent field value, shall be 0\tiec61883.6_incorrect_cip_fdf\tFT_NONE\tiec61883\t\t0x0\t']
#    _ws.col.Protocol found: False
#
# 🧾 Preview of first 10 packets:
#  frame.number,frame.time_relative,ip.src,ip.dst,_ws.col.Protocol,frame.len,_ws.col.Info
# 1,0.000000000,172.17.0.60,172.17.0.22,TCP,66,1031 → 20000 [ACK] Seq=1 Ack=1 Win=16367 Len=0
# 2,0.000320000,172.17.0.60,172.17.0.21,TCP,66,1030 → 20000 [ACK] Seq=1 Ack=1 Win=16384 Len=0
# 3,0.000860000,172.17.0.38,172.17.0.33,TCP,66,502 → 58980 [FIN, ACK] Seq=1 Ack=1 Win=264 Len=0
# 4,0.001152000,172.17.0.33,172.17.0.38,TCP,66,58980 → 502 [ACK] Seq=1 Ack=2 Win=8192 Len=0
# 5,0.074918000,172.17.0.32,172.17.0.38,TCP,66,
#  Tshark warnings/errors:
#  Running as user "root" and group "root". This could be dangerous.
#
# 🚀 Converting day1_02_10_20.pcap → day1_02_10_20.csv ...
#  Done: /content/scada_csv/day1_02_10_20.csv
#
#
#  Inspecting day3_03_16_20.pcap ...
# Could not summarize PCAP structure.
#
# 🔎 Checking field existence:
#    Example IP-related fields: ['F\tDescriptor Type\tieee17221.descriptor_type\tFT_UINT16\tieee17221\tBASE_HEX\t0x0\t', 'F\tDescriptor Index\tieee17221.descriptor_index\tFT_UINT16\tieee17221\tBASE_HEX\t0x0\t', 'F\tLocalized Description\tieee17221.configuration_name_string\tFT_UINT16\tieee17221\tBASE_DEC\t0x0\t']
#    Example Frame-related fields: ['F\tFrames TX\tieee17221.frames_tx\tFT_UINT32\tieee17221\tBASE_DEC\t0x0\t', 'F\tFrames RX\tieee17221.frames_rx\tFT_UINT32\tieee17221\tBASE_DEC\t0x0\t', 'F\tIncorrect frame dependent field value, shall be 0\tiec61883.6_incorrect_cip_fdf\tFT_NONE\tiec61883\t\t0x0\t']
#    _ws.col.Protocol found: False
#
# 🧾 Preview of first 10 packets:
#  frame.number,frame.time_relative,ip.src,ip.dst,_ws.col.Protocol,frame.len,_ws.col.Info
# 1,0.000000000,172.17.0.33,172.17.0.29,TCP,66,52246 → 502 [SYN] Seq=0 Win=8192 Len=0 MSS=1460
# 2,0.003342000,172.17.0.29,172.17.0.33,TCP,66,502 → 52246 [SYN, ACK] Seq=0 Ack=1 Win=264 Len=0 MSS=264
# 3,0.003621000,172.17.0.33,172.17.0.29,TCP,66,52246 → 502 [ACK] Seq=1 Ack=1 Win=8193 Len=0
# 4,0.003962000,172.17.0.33,172.17.0.29,Modbus/TCP,72,   Query: Trans:     0; Unit:   5, Func:   4: Read Input Registers
# 5,0.00870
#  Tshark warnings/errors:
#  Running as user "root" and group "root". This could be dangerous.
#
# 🚀 Converting day3_03_16_20.pcap → day3_03_16_20.csv ...
#  Done: /content/scada_csv/day3_03_16_20.csv
#
#
#  Inspecting day4_03_17_20.pcap ...
# Could not summarize PCAP structure.
#
# 🔎 Checking field existence:
#    Example IP-related fields: ['F\tDescriptor Type\tieee17221.descriptor_type\tFT_UINT16\tieee17221\tBASE_HEX\t0x0\t', 'F\tDescriptor Index\tieee17221.descriptor_index\tFT_UINT16\tieee17221\tBASE_HEX\t0x0\t', 'F\tLocalized Description\tieee17221.configuration_name_string\tFT_UINT16\tieee17221\tBASE_DEC\t0x0\t']
#    Example Frame-related fields: ['F\tFrames TX\tieee17221.frames_tx\tFT_UINT32\tieee17221\tBASE_DEC\t0x0\t', 'F\tFrames RX\tieee17221.frames_rx\tFT_UINT32\tieee17221\tBASE_DEC\t0x0\t', 'F\tIncorrect frame dependent field value, shall be 0\tiec61883.6_incorrect_cip_fdf\tFT_NONE\tiec61883\t\t0x0\t']
#    _ws.col.Protocol found: False
#
# 🧾 Preview of first 10 packets:
#  frame.number,frame.time_relative,ip.src,ip.dst,_ws.col.Protocol,frame.len,_ws.col.Info
# 1,0.000000000,172.17.0.60,172.17.0.22,DNP 3.0,84,Read, Class 123
# 2,0.005637000,172.17.0.22,172.17.0.60,DNP 3.0,77,Response
# 3,0.016351000,172.17.0.60,172.17.0.22,TCP,66,1028 → 20000 [ACK] Seq=25 Ack=18 Win=16367 Len=0
# 4,0.025615000,172.17.128.9,172.17.0.16,TCP,62,15253 → 23 [ACK] Seq=1 Ack=1 Win=510 Len=0
# 5,0.033699000,172.17.0.60,172.17.0.21,DNP 3.0,84,Read, Class 123
# 6,0.049021000,172.17.0.21,172.17.0.60,DNP
#  Tshark warnings/errors:
#  Running as user "root" and group "root". This could be dangerous.
#
# 🚀 Converting day4_03_17_20.pcap → day4_03_17_20.csv ...
#  Done: /content/scada_csv/day4_03_17_20.csv
#
#
#  Inspecting day5_03_18_20.pcap ...
# Could not summarize PCAP structure.
#
# 🔎 Checking field existence:
#    Example IP-related fields: ['F\tDescriptor Type\tieee17221.descriptor_type\tFT_UINT16\tieee17221\tBASE_HEX\t0x0\t', 'F\tDescriptor Index\tieee17221.descriptor_index\tFT_UINT16\tieee17221\tBASE_HEX\t0x0\t', 'F\tLocalized Description\tieee17221.configuration_name_string\tFT_UINT16\tieee17221\tBASE_DEC\t0x0\t']
#    Example Frame-related fields: ['F\tFrames TX\tieee17221.frames_tx\tFT_UINT32\tieee17221\tBASE_DEC\t0x0\t', 'F\tFrames RX\tieee17221.frames_rx\tFT_UINT32\tieee17221\tBASE_DEC\t0x0\t', 'F\tIncorrect frame dependent field value, shall be 0\tiec61883.6_incorrect_cip_fdf\tFT_NONE\tiec61883\t\t0x0\t']
#    _ws.col.Protocol found: False
#
# 🧾 Preview of first 10 packets:
#  frame.number,frame.time_relative,ip.src,ip.dst,_ws.col.Protocol,frame.len,_ws.col.Info
# 1,0.000000000,172.17.0.60,172.17.0.22,DNP 3.0,84,Read, Class 123
# 2,0.012278000,172.17.0.22,172.17.0.60,DNP 3.0,77,Response
# 3,0.016107000,172.17.0.60,172.17.0.22,TCP,66,1027 → 20000 [ACK] Seq=25 Ack=18 Win=16367 Len=0
# 4,0.016338000,172.17.0.60,172.17.0.21,TCP,66,1026 → 20000 [ACK] Seq=1 Ack=1 Win=16384 Len=0
# 5,0.033320000,172.17.128.9,172.17.0.19,TCP,62,46558 → 23 [ACK] Seq=1 Ack=1 Win=509 Len=0
# 6,0.034079000,1
#  Tshark warnings/errors:
#  Running as user "root" and group "root". This could be dangerous.
#
# 🚀 Converting day5_03_18_20.pcap → day5_03_18_20.csv ...
#  Done: /content/scada_csv/day5_03_18_20.csv
#
#
#  Inspecting day6_03_19_20.pcap ...
# Could not summarize PCAP structure.
#
# 🔎 Checking field existence:
#    Example IP-related fields: ['F\tDescriptor Type\tieee17221.descriptor_type\tFT_UINT16\tieee17221\tBASE_HEX\t0x0\t', 'F\tDescriptor Index\tieee17221.descriptor_index\tFT_UINT16\tieee17221\tBASE_HEX\t0x0\t', 'F\tLocalized Description\tieee17221.configuration_name_string\tFT_UINT16\tieee17221\tBASE_DEC\t0x0\t']
#    Example Frame-related fields: ['F\tFrames TX\tieee17221.frames_tx\tFT_UINT32\tieee17221\tBASE_DEC\t0x0\t', 'F\tFrames RX\tieee17221.frames_rx\tFT_UINT32\tieee17221\tBASE_DEC\t0x0\t', 'F\tIncorrect frame dependent field value, shall be 0\tiec61883.6_incorrect_cip_fdf\tFT_NONE\tiec61883\t\t0x0\t']
#    _ws.col.Protocol found: False
#
# 🧾 Preview of first 10 packets:
#  frame.number,frame.time_relative,ip.src,ip.dst,_ws.col.Protocol,frame.len,_ws.col.Info
# 1,0.000000000,172.17.0.60,172.17.0.21,TCP,66,1029 → 20000 [ACK] Seq=1 Ack=1 Win=16384 Len=0
# 2,0.000646000,172.17.0.60,172.17.0.16,DNP 3.0,96,Read, Class 123
# 3,0.001111000,172.17.0.16,172.17.0.60,TCP,72,20000 → 1024 [ACK] Seq=1 Ack=25 Win=8484 Len=0 TSval=4196824782 TSecr=87517
# 4,0.004008000,172.17.0.16,172.17.0.60,DNP 3.0,89,Response
# 5,0.033593000,172.17.0.60,172.17.0.16,TCP,72,1024 → 20000 [ACK] Seq=25 Ack=18
#  Tshark warnings/errors:
#  Running as user "root" and group "root". This could be dangerous.
#
# 🚀 Converting day6_03_19_20.pcap → day6_03_19_20.csv ...
#  Done: /content/scada_csv/day6_03_19_20.csv

# %%
import os, subprocess

pcap_dir = "/content/scada_data/Data/PCAPs/Long_duration_PCAPs"
proto_dir = "/content/protocol_csvs"
os.makedirs(proto_dir, exist_ok=True)

selected_pcaps = [
    "day1_02_10_20.pcap",
    "day3_03_16_20.pcap",
    "day4_03_17_20.pcap",
    "day5_03_18_20.pcap",
    "day6_03_19_20.pcap"
]

for fname in selected_pcaps:
    input_path = os.path.join(pcap_dir, fname)
    output_path = os.path.join(proto_dir, fname.replace(".pcap", "_protocols.csv"))

    print(f"Extracting protocols from {fname} ...")
    cmd = [
        "tshark",
        "-r", input_path,
        "-T", "fields",
        "-E", "header=y",
        "-E", "separator=,",
        "-e", "frame.number",
        "-e", "frame.protocols"
    ]
    with open(output_path, "w") as f:
        subprocess.run(cmd, stdout=f)
    print(f" Saved protocol CSV: {output_path}\n")
# Out:
# Extracting protocols from day1_02_10_20.pcap ...
#  Saved protocol CSV: /content/protocol_csvs/day1_02_10_20_protocols.csv
#
# Extracting protocols from day3_03_16_20.pcap ...
#  Saved protocol CSV: /content/protocol_csvs/day3_03_16_20_protocols.csv
#
# Extracting protocols from day4_03_17_20.pcap ...
#  Saved protocol CSV: /content/protocol_csvs/day4_03_17_20_protocols.csv
#
# Extracting protocols from day5_03_18_20.pcap ...
#  Saved protocol CSV: /content/protocol_csvs/day5_03_18_20_protocols.csv
#
# Extracting protocols from day6_03_19_20.pcap ...
#  Saved protocol CSV: /content/protocol_csvs/day6_03_19_20_protocols.csv

# %%
import pandas as pd

def robust_read_csv(path):
    """
    Safely read slightly malformed CSVs (e.g., commas inside Info column)
    without breaking parsing.
    """
    try:
        df = pd.read_csv(
            path,
            engine="python",        # slower but handles malformed lines
            on_bad_lines="skip",    # skip problematic lines instead of failing
            quotechar='"',          # handle quoted fields properly
            sep=",",                # comma separator
            error_bad_lines=False,  # backward compatibility (ignored in new pandas)
            warn_bad_lines=True
        )
    except Exception as e:
        print(f"⚠️ Error reading {path}: {e}")
        # fallback: manual re-split
        with open(path, "r", errors="ignore") as f:
            lines = f.readlines()
        header = lines[0].strip().split(",")
        data = [l.strip().split(",")[:len(header)] for l in lines[1:]]
        df = pd.DataFrame(data, columns=header)
    return df

# %%
# Python packages
# !pip install -q scikit-learn tensorflow pandas matplotlib seaborn networkx python-louvain tqdm ujson
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 kB 4.2 MB/s eta 0:00:00

# %% [markdown]
# ## saved the dataset to drive, reopening the uploaded data from drive

# %%
import os
import glob
import pandas as pd
from zipfile import ZipFile

# ----- Unzip folder -----
zip_path = '/content/drive/MyDrive/scada_csv_backup.zip'
extract_dir = '/content/scada_csv_extracted'
os.makedirs(extract_dir, exist_ok=True)
with ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

# ----- Output dir -----
OUT_DIR = '/content/scada_analysis'
os.makedirs(OUT_DIR, exist_ok=True)

# ----- List CSVs -----
csvs = sorted(glob.glob(os.path.join(extract_dir, '*.csv')))
print("Found CSVs:", csvs)

# ----- Read CSVs (only first 7 columns) -----
for file in csvs:
    try:
        # Read first 7 columns by index
        df = pd.read_csv(file, usecols=range(7), engine='python')  # <- key!

        print(f"\nFile: {file}")
        print(f"Rows: {len(df)}, Columns: {len(df.columns)}")
        print(df.head(3))

        # Save cleaned CSV
        out_file = os.path.join(OUT_DIR, os.path.basename(file))
        df.to_csv(out_file, index=False)

    except Exception as e:
        print(f"Error reading {file}: {e}")
# Out:
# Found CSVs: ['/content/scada_csv_extracted/day1_02_10_20.csv', '/content/scada_csv_extracted/day3_03_16_20.csv', '/content/scada_csv_extracted/day4_03_17_20.csv', '/content/scada_csv_extracted/day5_03_18_20.csv', '/content/scada_csv_extracted/day6_03_19_20.csv']
#
# File: /content/scada_csv_extracted/day1_02_10_20.csv
# Rows: 5522384, Columns: 7
#    frame.number  frame.time_relative       ip.src       ip.dst  \
# 0             1              0.00000  172.17.0.60  172.17.0.22
# 1             2              0.00032  172.17.0.60  172.17.0.21
# 2             3              0.00086  172.17.0.38  172.17.0.33
#
#   _ws.col.Protocol frame.len                                    _ws.col.Info
# 0              TCP        66  1031 → 20000 [ACK] Seq=1 Ack=1 Win=16367 Len=0
# 1              TCP        66  1030 → 20000 [ACK] Seq=1 Ack=1 Win=16384 Len=0
# 2              TCP        66                                502 → 58980 [FIN
#
# File: /content/scada_csv_extracted/day3_03_16_20.csv
# Rows: 2950364, Columns: 7
#    frame.number  frame.time_relative       ip.src       ip.dst  \
# 0             1             0.000000  172.17.0.33  172.17.0.29
# 1             2             0.003342  172.17.0.29  172.17.0.33
# 2             3             0.003621  172.17.0.33  172.17.0.29
#
#   _ws.col.Protocol frame.len                                     _ws.col.Info
# 0              TCP        66  52246 → 502 [SYN] Seq=0 Win=8192 Len=0 MSS=1460
# 1              TCP        66                                 502 → 52246 [SYN
# 2              TCP        66     52246 → 502 [ACK] Seq=1 Ack=1 Win=8193 Len=0
#
# File: /content/scada_csv_extracted/day4_03_17_20.csv
# Rows: 2389168, Columns: 7
#    frame.number frame.time_relative       ip.src   ip.dst _ws.col.Protocol  \
# 1      0.000000         172.17.0.60  172.17.0.22  DNP 3.0               84
# 2      0.005637         172.17.0.22  172.17.0.60  DNP 3.0               77
# 3      0.016351         172.17.0.60  172.17.0.22      TCP               66
#
#                                           frame.len _ws.col.Info
# 1                                              Read    Class 123
# 2                                          Response         None
# 3  1028 → 20000 [ACK] Seq=25 Ack=18 Win=16367 Len=0         None
#
# File: /content/scada_csv_extracted/day5_03_18_20.csv
# Rows: 2645067, Columns: 7
#    frame.number frame.time_relative       ip.src   ip.dst _ws.col.Protocol  \
# 1      0.000000         172.17.0.60  172.17.0.22  DNP 3.0               84
# 2      0.012278         172.17.0.22  172.17.0.60  DNP 3.0               77
# 3      0.016107         172.17.0.60  172.17.0.22      TCP               66
#
#                                           frame.len _ws.col.Info
# 1                                              Read    Class 123
# 2                                          Response         None
# 3  1027 → 20000 [ACK] Seq=25 Ack=18 Win=16367 Len=0         None
#
# File: /content/scada_csv_extracted/day6_03_19_20.csv
# Rows: 2551495, Columns: 7
#    frame.number  frame.time_relative       ip.src       ip.dst  \
# 0             1             0.000000  172.17.0.60  172.17.0.21
# 1             2             0.000646  172.17.0.60  172.17.0.16
# 2             3             0.001111  172.17.0.16  172.17.0.60
#
#   _ws.col.Protocol frame.len  \
# 0              TCP        66
# 1          DNP 3.0        96
# 2              TCP        72
#
#                                         _ws.col.Info
# 0     1029 → 20000 [ACK] Seq=1 Ack=1 Win=16384 Len=0
# 1                                               Read
# 2  20000 → 1024 [ACK] Seq=1 Ack=25 Win=8484 Len=0...

# %% [markdown]
# ## Standardize columns , canonical protocol extraction
#
# We create canonical columns: frame.number (int), time (float), ip.src, ip.dst, src_port, dst_port, protocol (final layer like modbus), frame.len, info.

# %%
import os
import glob
import pandas as pd
import numpy as np
from zipfile import ZipFile
from pathlib import Path

OUT_DIR = '/content/scada_analysis'
std_dir = os.path.join(OUT_DIR, "standardized")
os.makedirs(std_dir, exist_ok=True)

# ------------------- List CSV files -------------------
csvs = sorted(glob.glob(os.path.join(extract_dir, '*.csv')))
print("Found CSVs:", csvs)

# ------------------- Canonicalization function -------------------
def canonicalize_df(df):
    # frame.number
    if 'frame.number' not in df.columns:
        for c in df.columns:
            if 'frame.number' in c:
                df = df.rename(columns={c:'frame.number'})
                break
    df['frame.number'] = pd.to_numeric(df.get('frame.number'), errors='coerce').astype('Int64')

    # time column
    time_cols = [c for c in df.columns if 'time' in c.lower()]
    if time_cols:
        df['time_rel'] = pd.to_numeric(df[time_cols[0]], errors='coerce')
    else:
        df['time_rel'] = pd.NA

    # IP columns
    for c in df.columns:
        if c.lower().strip() in ('ip.src','ip.src.addr','src'):
            df = df.rename(columns={c:'ip.src'})
        if c.lower().strip() in ('ip.dst','ip.dst.addr','dst'):
            df = df.rename(columns={c:'ip.dst'})

    # frame.len
    if 'frame.len' not in df.columns:
        for c in df.columns:
            if 'len' in c.lower() and 'frame' in c.lower():
                df = df.rename(columns={c:'frame.len'})
                break
    df['frame.len'] = pd.to_numeric(df.get('frame.len'), errors='coerce')

    # info column
    for c in df.columns:
        if '_ws.col.info' in c.lower() or c.lower() == 'info':
            df = df.rename(columns={c:'info'})
            break

    # protocol
    if 'protocol' not in df.columns:
        candidates = [c for c in df.columns if 'protocol' in c.lower()]
        if candidates:
            df = df.rename(columns={candidates[0]:'protocol'})
    if 'protocol' in df.columns:
        df['protocol'] = df['protocol'].astype(str).fillna('').str.split(':').str[-1].replace('', np.nan)

    # TCP/UDP ports
    for col in list(df.columns):
        if 'tcp.srcport' in col.lower() or col.lower() == 'tcp.srcport':
            df = df.rename(columns={col:'tcp.srcport'})
        if 'tcp.dstport' in col.lower() or col.lower() == 'tcp.dstport':
            df = df.rename(columns={col:'tcp.dstport'})
    # generic src/dst port
    for col in list(df.columns):
        if 'srcport' in col.lower() and 'tcp' not in col.lower():
            df = df.rename(columns={col:'tcp.srcport'})
        if 'dstport' in col.lower() and 'tcp' not in col.lower():
            df = df.rename(columns={col:'tcp.dstport'})

    # cast ports
    for p in ['tcp.srcport', 'tcp.dstport']:
        if p in df.columns:
            df[p] = pd.to_numeric(df[p], errors='coerce').astype('Int64')

    return df

# ------------------- 5. Read, canonicalize, save -------------------
for path in csvs:
    try:
        # Only read first 7 columns to avoid parser errors
        df = pd.read_csv(path, usecols=range(7), engine='python')
        df = canonicalize_df(df)

        out_file = os.path.join(std_dir, Path(path).stem + "_std.csv")
        df.to_csv(out_file, index=False)
        print(f"Standardized and saved: {out_file}")

    except Exception as e:
        print(f"Error reading {path}: {e}")

print("\nAll standardized CSVs saved to:", std_dir)
# Out:
# Unzipped CSVs to: /content/scada_csv_extracted
# Found CSVs: ['/content/scada_csv_extracted/day1_02_10_20.csv', '/content/scada_csv_extracted/day3_03_16_20.csv', '/content/scada_csv_extracted/day4_03_17_20.csv', '/content/scada_csv_extracted/day5_03_18_20.csv', '/content/scada_csv_extracted/day6_03_19_20.csv']
# Standardized and saved: /content/scada_analysis/standardized/day1_02_10_20_std.csv
# Standardized and saved: /content/scada_analysis/standardized/day3_03_16_20_std.csv
# Error reading /content/scada_csv_extracted/day4_03_17_20.csv: cannot safely cast non-equivalent object to int64
# Error reading /content/scada_csv_extracted/day5_03_18_20.csv: cannot safely cast non-equivalent object to int64
# Standardized and saved: /content/scada_analysis/standardized/day6_03_19_20_std.csv
#
# All standardized CSVs saved to: /content/scada_analysis/standardized

# %% [markdown]
# ## FEATURE ENGINEERING:  Build protocol when missing (port mapping + info keyword)
#
# We synthesize protocol_final using these rules:
#
# existing protocol column → split last layer
#
# port mapping: dstport 502 → modbus; 20000 → dnp3
#
# _ws.col.Info keyword match (modbus, dnp3, read, write)
#
# fallback: tcp / udp / unknown

# %%
import glob, pandas as pd

port_map = {502:'modbus', 20000:'dnp3', 2404:'iec104', 44818:'ethernetip'}  # add as needed
std_files = sorted(glob.glob(std_dir + "/*_std.csv"))

for f in std_files:
    df = pd.read_csv(f, low_memory=False)
    # derive from existing protocol if present
    if 'protocol' in df.columns:
        proto = df['protocol'].astype(str).str.lower().str.split(':').str[-1]
    else:
        proto = pd.Series([pd.NA]*len(df))

    # port-based
    if 'tcp.dstport' in df.columns:
        port_proto = df['tcp.dstport'].map(port_map).fillna(pd.NA)
    else:
        port_proto = pd.Series([pd.NA]*len(df))

    # info-based fuzzy match
    info_proto = pd.Series([pd.NA]*len(df))
    if 'info' in df.columns:
        info_lower = df['info'].astype(str).str.lower()
        info_proto = info_lower.str.extract('(modbus|dnp3|iec104|ethernetip)', expand=False)

    # combine with priority: protocol > port_proto > info_proto > frame.protocols_last_token > fallback
    df['protocol_final'] = proto.fillna(port_proto).fillna(info_proto)
    # try falling back to frame.protocols if present
    if 'frame.protocols' in df.columns and df['protocol_final'].isna().any():
        df['protocol_final'] = df['protocol_final'].fillna(df['frame.protocols'].astype(str).str.split(':').str[-1])
    df['protocol_final'] = df['protocol_final'].fillna('tcp').fillna('unknown')
    # save
    df.to_csv(f.replace("_std.csv","_std_proto.csv"), index=False)
print("protocol_final added to all standardized CSVs")
# Out:
# protocol_final added to all standardized CSVs

# %% [markdown]
# ## Add class Labeling (Day1 → Normal; Days3–6 → Attack)
#
# these dyas are categorised in the original paper

# %%
label_map = {
    "day1_02_10_20": "Normal",
    "day3_03_16_20": "Attack",
    "day4_03_17_20": "Attack",
    "day5_03_18_20": "Attack",
    "day6_03_19_20": "Attack"
}

proto_files = sorted(glob.glob(std_dir + "/*_std_proto.csv"))
dfs = []
for f in proto_files:
    stem = Path(f).stem.replace("_std_proto", "")
    if stem not in label_map:
        print("Skipping", stem)
        continue
    df = pd.read_csv(f, low_memory=False)
    df['day_label'] = label_map[stem]
    df['source_file'] = stem
    dfs.append(df[['frame.number','time_rel','ip.src','ip.dst','frame.len','info','protocol_final','day_label','source_file']])
full = pd.concat(dfs, ignore_index=True)
full.to_csv(os.path.join(OUT_DIR,"scada_full_raw.csv"), index=False)
print("Combined dataset shape:", full.shape)
# Out:
# Combined dataset shape: (11024243, 9)

# %%
full.head()
# Out:
#    frame.number  time_rel       ip.src       ip.dst  frame.len  \
# 0             1  0.000000  172.17.0.60  172.17.0.22       66.0
# 1             2  0.000320  172.17.0.60  172.17.0.21       66.0
# 2             3  0.000860  172.17.0.38  172.17.0.33       66.0
# 3             4  0.001152  172.17.0.33  172.17.0.38       66.0
# 4             5  0.074918  172.17.0.32  172.17.0.38       66.0
#
#                                               info protocol_final day_label  \
# 0   1031 → 20000 [ACK] Seq=1 Ack=1 Win=16367 Len=0            tcp    Normal
# 1   1030 → 20000 [ACK] Seq=1 Ack=1 Win=16384 Len=0            tcp    Normal
# 2                                 502 → 58980 [FIN            tcp    Normal
# 3     58980 → 502 [ACK] Seq=1 Ack=2 Win=8192 Len=0            tcp    Normal
# 4  65001 → 502 [SYN] Seq=0 Win=4096 Len=0 MSS=1460            tcp    Normal
#
#      source_file
# 0  day1_02_10_20
# 1  day1_02_10_20
# 2  day1_02_10_20
# 3  day1_02_10_20
# 4  day1_02_10_20

# %% [markdown]
# now we have saved scada_full_raw for further processing.
